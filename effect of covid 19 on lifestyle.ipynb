# %% [markdown]
# # Project Name=Effect of covid 19 on lifestyle

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("psyco.csv")

# %%
df.head()
# Out:
#       age  gender          occupation line_of_work  time_bp  time_dp  \
# 0   19-25    Male  Student in College          NaN        7        5
# 1  Dec-18    Male   Student in School          NaN        7       11
# 2   19-25    Male  Student in College          NaN        7        7
# 3   19-25    Male  Student in College          NaN        7        7
# 4   19-25  Female  Student in College          NaN        7        7
#
#    travel_time  easeof_online  home_env  prod_inc  ...  fam_connect  relaxed  \
# 0          0.5              3         3       0.0  ...          1.0     -0.5
# 1          0.5              4         2      -0.5  ...          1.0      1.0
# 2          1.5              2         2       1.0  ...          0.5      0.5
# 3          1.5              3         1       0.0  ...          0.0     -1.0
# 4          1.5              2         2       0.0  ...          0.0      0.5
#
#    self_time  like_hw  dislike_hw                        prefer  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'occupation', 'line_of_work', 'time_bp', 'time_dp',
#        'travel_time', 'easeof_online', 'home_env', 'prod_inc', 'sleep_bal',
#        'new_skill', 'fam_connect', 'relaxed', 'self_time', 'like_hw',
#        'dislike_hw', 'prefer', 'certaindays_hw', 'Unnamed: 19', 'time_bp.1',
#        'travel+work'],
#       dtype='object')

# %%
df.shape
# Out:
# (1175, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175 entries, 0 to 1174
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1175 non-null   object
#  1   gender          1175 non-null   object
#  2   occupation      1175 non-null   object
#  3   line_of_work    479 non-null    object
#  4   time_bp         1175 non-null   int64
#  5   time_dp         1175 non-null   int64
#  6   travel_time     1175 non-null   float64
#  7   easeof_online   1175 non-null   int64
#  8   home_env        1175 non-null   int64
#  9   prod_inc        1175 non-null   float64
#  10  sleep_bal       1175 non-null   float64
#  11  new_skill       1175 non-null   float64
#  12  fam_connect     1175 non-null   float64
#  13  relaxed         1175 non-null   float64
#  14  self_time       1175 non-null   float64
#  15  like_hw         1175 non-null   int64
#  16  dislike_hw      1175 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# age                  0
# gender               0
# occupation           0
# line_of_work       696
# time_bp              0
# time_dp              0
# travel_time          0
# easeof_online        0
# home_env             0
# prod_inc             0
# sleep_bal            0
# new_skill            0
# fam_connect          0
# relaxed              0
# self_time            0
# like_hw              0
# dislike_hw           0
# prefer               0
# certaindays_hw       0
# Unnamed: 19       1175
# time_bp.1            0
# travel+work       1175
# dtype: int64

# %%
# Remove unnecessary columns
df = df.drop(columns=['Unnamed: 19', 'time_bp.1', 'travel+work'])

# %%
df.describe()
# Out:
#            time_bp      time_dp  travel_time  easeof_online     home_env  \
# count  1175.000000  1175.000000  1175.000000    1175.000000  1175.000000
# mean      7.415319     7.971915     1.027660       2.533617     2.752340
# std       2.005385     2.657007     0.713314       1.267609     1.235799
# min       4.000000     4.000000     0.500000       1.000000     1.000000
# 25%       5.000000     5.000000     0.500000       1.000000     2.000000
# 50%       7.000000     9.000000     0.500000       2.000000     3.000000
# 75%       9.000000     9.000000     1.500000       4.000000     4.000000
# max      12.000000    12.000000     3.000000       5.000000     5.000000
#
#           prod_inc    sleep_bal    new_skill  fam_connect      relaxed  \
# count  1175.000000  1175.000000  1175.000000  1175.000000  1175.000000
# mean      0.008936    -0.108936     0.146809     0.260426     0.035745
# std       0.615083     0.621215     0.643686     0.686825     0.626637
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings("ignore")

# %%
plt.figure(figsize = (12,8))
sns.heatmap(df.corr() , annot =True , cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
# Bar chart for 'occupation'
plt.figure(figsize=(10, 6))
df['occupation'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Occupation Distribution')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.show()

# %%
# Bar chart for 'line_of_work'
plt.figure(figsize=(10, 6))
df['line_of_work'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Line of Work Distribution')
plt.xlabel('Line of Work')
plt.ylabel('Count')
plt.show()

# %%
# Histogram for 'time_bp'
plt.figure(figsize=(10, 6))
plt.hist(df['time_bp'], bins=10, color='orange', edgecolor='black')
plt.title('Time Spend on Work Before Pandemic Distribution')
plt.xlabel('Time (hours)')
plt.ylabel('Count')
plt.show()

# %%
# Histogram for 'time_dp'
plt.figure(figsize=(10, 6))
plt.hist(df['time_dp'], bins=10, color='g', edgecolor='black')
plt.title('Time Spend On Work During Pandemic Distribution')
plt.xlabel('Time (hours)')
plt.ylabel('Count')
plt.show()

# %%
# Histogram for 'travel_time'
plt.figure(figsize=(10, 6))
plt.hist(df['travel_time'], bins=10, color='hotpink', edgecolor='black')
plt.title('Travel Time Distribution')
plt.xlabel('Time (hours)')
plt.ylabel('Count')
plt.show()

# %%
# Histogram for 'easeof_online' means rating of work going online.
plt.figure(figsize=(8, 6))
plt.hist(df['easeof_online'], bins=5, color='skyblue', edgecolor='black')
plt.title('Ease of Online Work Distribution')
plt.xlabel('Ease Score')
plt.ylabel('Count')
plt.show()

# %%
# Set up the matplotlib figure
fig, axs = plt.subplots(6, 1, figsize=(10, 40))

# Boxplot for 'prod_inc'
sns.histplot(y=df['prod_inc'], ax=axs[0], color='Green')
axs[0].set_title('Productivity Increase Distribution')

# Boxplot for 'sleep_bal'
sns.boxplot(y=df['sleep_bal'], ax=axs[1], color='hotpink')
axs[1].set_title('Sleep Balance Distribution')

# Boxplot for 'new_skill'
sns.boxplot(y=df['new_skill'], ax=axs[2], color='orange')
axs[2].set_title('New Skill Acquisition Distribution')

# Boxplot for 'fam_connect'
sns.boxplot(y=df['fam_connect'], ax=axs[3], color='skyblue')
axs[3].set_title('Family Connection Distribution')

# Boxplot for 'relaxed'
sns.boxplot(y=df['relaxed'], ax=axs[4], color='skyblue')
axs[4].set_title('Relaxation Distribution')

# Boxplot for 'self_time'
sns.boxplot(y=df['self_time'], ax=axs[5], color='r')
axs[5].set_title('Self Time Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Insights from Visualization:**
#
#
# **1.** **Bar Charts**
#
# * ***Occupation Distribution***: The most common occupation among the respondents is 'Working Professional', followed by 'Student in College'. The 'Other' category also has a significant number of respondents.
#
# * ***Line of Work Distribution***: Teaching is the most common line of work among the respondents, followed by 'Engineering/Architecture' and 'Other'.
#
# **2. Histograms**
#
# * ***Time Before Pandemic Distribution***: The most common time spent before the pandemic is around 7 hours, with a significant number of respondents also spending around 9 hours.
#
# * ***Time During Pandemic Distribution***: The most common time spent during the pandemic is 9 hours, with a significant number of respondents also spending around 7 hours.
#
# * ***Travel Time Distribution***: Most respondents spend half an hour traveling.
#
# * ***Ease of Online Work Distribution***: The most common score for the ease of online work is 2, which suggests a moderate level of ease.
#
#
#
# **3. Box Plots**
#
# * ***Productivity Increase Distribution*** The median productivity increase score is 0, with a few outliers on both sides. This suggests that most respondents did not see a significant change in their productivity.
#
# * ***Sleep Balance Distribution***: The median sleep balance score is 0, with a few outliers on both sides. This suggests that most respondents did not see a significant change in their sleep balance.
#
# * ***New Skill Acquisition Distribution***: The median score for new skill acquisition is 0.5, with a few outliers on both sides. This suggests that some respondents were able to acquire new skills.
#
# * ***Family Connection Distribution***: The median family connection score is 0.5, with a few outliers on the negative side. This suggests that some respondents were able to increase their family connections.
#
# * ***Relaxation Distribution***: The median relaxation score is 0, with a few outliers on both sides. This suggests that most respondents did not see a significant change in their level of relaxation.
#
# * ***Self Time Distribution***: The median self-time score is 0, with a few outliers on both sides. This suggests that most respondents did not see a significant change in their self-time.

# %% [markdown]
# ### More Visulaizations

# %%
# Set up the matplotlib figure
fig, axs = plt.subplots(2, 1, figsize=(10, 30))

# Countplot for 'occupation' split by 'gender'
sns.countplot(x='occupation', hue='gender', data=df, ax=axs[0],palette='viridis')
axs[0].set_title('Occupation by Gender')
axs[0].set_xlabel('Occupation')
axs[0].set_ylabel('Count')
axs[0].tick_params(axis='x', rotation=45)

# Countplot for 'prefer' split by 'gender'
sns.countplot(x='prefer', hue='gender', data=df, ax=axs[1], palette='viridis')
axs[1].set_title('Preference for Attendance Mode by Gender')
axs[1].set_xlabel('Preference')
axs[1].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### **Insights of Visualization**
#
# **1. Occupation by Gender:** The 'Working Professional' occupation has the highest representation of both males and females. There's also a relatively balanced gender representation in the 'Student in College' category. For other categories, the gender distribution seems to skew towards one gender.
#
# **2. Preference for Attendance Mode by Gender:** Both males and females predominantly prefer 'Complete Physical Attendance'. However, a sizable minority in both genders prefers a 'Mix of Online and Physical Attendance'.

# %% [markdown]
# ## **Objective:** Classification of individuals based on lifestyle changes
#
# * Let's consider that a person has significantly changed their lifestyle if they have experienced an increase or decrease of more than 0.5 in at least one of the following variables: ***prod_inc, sleep_bal, new_skill, fam_connect, relaxed,*** and ***self_time***.
#
# * We'll create a new binary variable named ***lifestyle_change*** where 1 represents a significant lifestyle change and 0 represents no significant lifestyle change.

# %%
data = df.copy()

# %%
# Create a new binary variable 'lifestyle_change'
change_columns = ['prod_inc', 'sleep_bal', 'new_skill', 'fam_connect', 'relaxed', 'self_time']
data['lifestyle_change'] = data[change_columns].apply(lambda row: np.any(np.abs(row) > 0.5), axis=1).astype(int)

# Display the first few rows of the dataset
data.head()
# Out:
#       age  gender          occupation line_of_work  time_bp  time_dp  \
# 0   19-25    Male  Student in College          NaN        7        5
# 1  Dec-18    Male   Student in School          NaN        7       11
# 2   19-25    Male  Student in College          NaN        7        7
# 3   19-25    Male  Student in College          NaN        7        7
# 4   19-25  Female  Student in College          NaN        7        7
#
#    travel_time  easeof_online  home_env  prod_inc  sleep_bal  new_skill  \
# 0          0.5              3         3       0.0        0.0        0.5
# 1          0.5              4         2      -0.5        0.5       -1.0
# 2          1.5              2         2       1.0        0.0        0.5
# 3          1.5              3         1       0.0        1.0        0.5
# 4          1.5              2         2       0.0        0.0        0.0
#
#    fam_connect  relaxed  self_time  like_hw  dislike_hw  \
# 0          1.0     -0.5       -0.5      100           1
# ...

# %%
# Check the balance of classes in 'lifestyle_change'
data['lifestyle_change'].value_counts(normalize=True)
# Out:
# 1    0.64766
# 0    0.35234
# Name: lifestyle_change, dtype: float64

# %% [markdown]
# # About 65% of the individuals in the dataset experienced a significant lifestyle change (lifestyle_change = 1), while the remaining 35% did not experience a significant lifestyle change (lifestyle_change = 0).

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data['occupation'] = le.fit_transform(df['occupation'])
data['line_of_work'] = le.fit_transform(df['line_of_work'].astype(str))
data['prefer'] = le.fit_transform(df['prefer'])
data['certaindays_hw'] = le.fit_transform(df['certaindays_hw'])
data['age']=le.fit_transform(df['age'].astype(str))
data['gender']=le.fit_transform(df['gender'].astype(str))

# %%
data
# Out:
#       age  gender  occupation  line_of_work  time_bp  time_dp  travel_time  \
# 0       0       1           5             8        7        5          0.5
# 1       6       1           6             8        7       11          0.5
# 2       0       1           5             8        7        7          1.5
# 3       0       1           5             8        7        7          1.5
# 4       0       0           5             8        7        7          1.5
# ...   ...     ...         ...           ...      ...      ...          ...
# 1170    3       0           1             8        9        9          0.5
# 1171    1       0           2             8        5       12          0.5
# 1172    1       1           7             3        9       11          0.5
# 1173    1       1           7             3       11       12          1.5
# 1174    3       1           7             3        5        5          0.5
#
# ...

# %%
#X=data.iloc[:,0:-1]#-1 it means we drop dependent variable that is target column
#y=data.iloc[:,-1]
X=data.drop('lifestyle_change',axis=1)
y=data.lifestyle_change

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=50)

print('Shape of X_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X_train =  (881, 19)
# Shape of y_train =  (881,)
# Shape of X_test =  (294, 19)
# Shape of y_test =  (294,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()#feature scaling
sc.fit(X_train) 
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
classification_rbf = SVC(kernel='rbf')#Gaussian kernel is non linear kernel function.
classification_rbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
accu_svc=classification_rbf.score(X_test, y_test)
accu_svc
# Out:
# 0.9319727891156463

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators=100, criterion='gini')
classifier.fit(X_train, y_train)
y_pred = classifier.predict

# %%
print("Random Forest Training Accuracy:", classifier.score(X_train , y_train))
print("Random Forest Testing Accuracy:", classifier.score(X_test , y_test))
# Out:
# Random Forest Training Accuracy: 1.0
# Random Forest Testing Accuracy: 0.9829931972789115

# %%
accu_rfc=classifier.score(X_test,y_test)
accu_rfc
# Out:
# 0.9829931972789115

# %%
from sklearn.model_selection import cross_val_score

# %%
score_rf=cross_val_score(RandomForestClassifier(n_estimators=100),X,y,cv=5)
print(score_rf)
print("Avg:",np.average(score_rf))
# Out:
# [0.90638298 0.93191489 1.         1.         1.        ]
# Avg: 0.9676595744680851

# %%
plt.figure(figsize=(12,6))
model_acc = [accu_svc,accu_rfc]
model_name = ['SVC','RandomForestClassifier']
sns.barplot(x=model_acc, y=model_name,palette='viridis')
# Out:
# <Axes: >

# %%
y_pred = classifier .predict(X_test)
y_pred

y_pred = classifier.predict(X_test)
df3 = pd.DataFrame({"Y_test": y_test , "Y_pred" : y_pred})
df3.head(20)
# Out:
#       Y_test  Y_pred
# 752        1       1
# 703        1       1
# 120        1       1
# 331        1       1
# 163        0       0
# 1124       0       0
# 598        1       1
# 166        1       1
# 104        1       1
# 819        1       1
# 1004       1       1
# 839        0       0
# 312        0       0
# 1002       1       1
# 500        0       0
# 796        1       1
# 702        0       0
# 1019       1       1
# 1171       1       1
# 399        1       1

# %%
first=[0,1,5,8,7,5,0.5,3,3,0.0,0.0,0.5,1.0,-0.5,-0.5,100,1,0,2]

# %%
first= np.array([first])
first
# Out:
# array([[  0. ,   1. ,   5. ,   8. ,   7. ,   5. ,   0.5,   3. ,   3. ,
#           0. ,   0. ,   0.5,   1. ,  -0.5,  -0.5, 100. ,   1. ,   0. ,
#           2. ]])

# %%
classifier.predict(first)
# Out:
# array([1])

# %%
pred = classifier.predict(first)
 
if pred[0] == 0:
  print('lifestyle do not change')
else:
  print('lifestyle change')
# Out:
# lifestyle change

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f'Root Mean Squared Error: {rmse}')
print(f'mean square error:{mse}')
# Out:
# Root Mean Squared Error: 0.13041013273932528
# mean square error:0.017006802721088437
